# %% [markdown]
# # In actual practical test itself, the questions will be in MCQ format with open-ended questions.
#
# This is mock practical test section B is to let you practice your coding <br>
# Download the hdb data set here https://data.gov.sg/datasets/d_8b84c4ee58e3cfc0ece0d773c8ca6abc/view<br>
# Run the following code block before you begin answering the questions

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import joblib

# %%
def storey_checker(txt,storey_threshold):
    temp=[int(s) for s in txt.split() if s.isdigit()]
    return all([i<storey_threshold for i in temp])

# %%
df=pd.read_csv(r'resale-flat.csv')

# The following pre-processing is to make the dataset more manageable for this mock only

#process blocks as integers, removing the last character if it's a letter
df['block']=df['block'].apply(lambda x: int(x[:-1]) if x[-1].isalpha() else int(x))

#keep rows with ['SENGKANG', 'BISHAN', 'WOODLANDS', 'TAMPINES', 'BEDOK', 'PUNGGOL']
df = df[df['town'].isin(['TAMPINES', 'BEDOK', 'PUNGGOL'])]

#keep rows with the word 'ROOM' in the flat_type column
df = df[df['flat_type'].str.contains('ROOM', case=False)]

#keep rows with integer values in storey_range less than 10
df = df[df['storey_range'].apply(lambda x: storey_checker(x, 10))]

df
# Out:
#           month      town flat_type  block      street_name storey_range  \
# 56      2017-01     BEDOK    2 ROOM    101  BEDOK NTH AVE 4     04 TO 06
# 57      2017-01     BEDOK    3 ROOM    548  BEDOK NTH AVE 1     04 TO 06
# 58      2017-01     BEDOK    3 ROOM     75     BEDOK NTH RD     07 TO 09
# 59      2017-01     BEDOK    3 ROOM    550  BEDOK NTH AVE 1     01 TO 03
# 60      2017-01     BEDOK    3 ROOM      1  BEDOK STH AVE 1     01 TO 03
# ...         ...       ...       ...    ...              ...          ...
# 205835  2025-05  TAMPINES    5 ROOM    876   TAMPINES ST 84     04 TO 06
# 205836  2025-01  TAMPINES    5 ROOM    871   TAMPINES ST 86     04 TO 06
# 205837  2025-01  TAMPINES    5 ROOM    871   TAMPINES ST 86     04 TO 06
# 205839  2025-04  TAMPINES    5 ROOM    932   TAMPINES ST 91     04 TO 06
# 205840  2025-05  TAMPINES    5 ROOM    912   TAMPINES ST 91     04 TO 06
#
#         floor_area_sqm      flat_model  lease_commence_date  \
# 56                45.0        Improved                 1978
# 57                68.0  New Generation                 1980
# 58                59.0        Improved                 1978
# 59                68.0  New Generation                 1980
# 60                59.0        Improved                 1976
# ...                ...             ...                  ...
# 205835           122.0        Improved                 1988
# 205836           114.0        Improved                 2017
# 205837           114.0        Improved                 2017
# 205839           138.0         Model A                 1985
# 205840           134.0         Model A                 1984
#
#            remaining_lease  resale_price
# 56      60 years 06 months      238000.0
# 57      62 years 06 months      272000.0
# 58                60 years      278000.0
# 59      62 years 05 months      280000.0
# 60                58 years      280000.0
# ...                    ...           ...
# 205835  62 years 03 months      740000.0
# 205836  91 years 03 months      840000.0
# 205837  91 years 02 months      812000.0
# 205839  59 years 09 months      808000.0
# 205840  58 years 05 months      818000.0
#
# [23747 rows x 11 columns]

# %% [markdown]
# What “Town” occured the most number of times?

# %%
town_column = df["town"]

greatest_frequency_town = town_column.value_counts().idxmax()

print(f"The town that occured the greatest number of times is {greatest_frequency_town.lower()}.")
# Out:
# The town that occured the greatest number of times is tampines.

# %%
df["flat_type"].unique()
# Out:
# array(['2 ROOM', '3 ROOM', '4 ROOM', '5 ROOM'], dtype=object)

# %% [markdown]
# Drop the following columns, 'month', 'street_name', 'flat_model', and 'remaining_lease'

# %%
df.drop(["month","street_name", "flat_model", "remaining_lease"], axis=1)
# Out:
#             town flat_type  block storey_range  floor_area_sqm  \
# 56         BEDOK    2 ROOM    101     04 TO 06            45.0
# 57         BEDOK    3 ROOM    548     04 TO 06            68.0
# 58         BEDOK    3 ROOM     75     07 TO 09            59.0
# 59         BEDOK    3 ROOM    550     01 TO 03            68.0
# 60         BEDOK    3 ROOM      1     01 TO 03            59.0
# ...          ...       ...    ...          ...             ...
# 205835  TAMPINES    5 ROOM    876     04 TO 06           122.0
# 205836  TAMPINES    5 ROOM    871     04 TO 06           114.0
# 205837  TAMPINES    5 ROOM    871     04 TO 06           114.0
# 205839  TAMPINES    5 ROOM    932     04 TO 06           138.0
# 205840  TAMPINES    5 ROOM    912     04 TO 06           134.0
#
#         lease_commence_date  resale_price
# 56                     1978      238000.0
# 57                     1980      272000.0
# 58                     1978      278000.0
# 59                     1980      280000.0
# 60                     1976      280000.0
# ...                     ...           ...
# 205835                 1988      740000.0
# 205836                 2017      840000.0
# 205837                 2017      812000.0
# 205839                 1985      808000.0
# 205840                 1984      818000.0
#
# [23747 rows x 7 columns]

# %% [markdown]
# Perform one hot encoding on required remaining columns.

# %%
df = pd.get_dummies(df)

# %% [markdown]
# Train test split the data using random_state=5, using 20% of the data as testing.

# %%
X = df.drop(["resale_price"], axis=1)#.to_numpy()
y = df["resale_price"]#.to_numpy()

seed = 5
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=seed, 
                                                    test_size=test_size,
                                                    )

# %% [markdown]
# Train a linear regression model

# %%
from sklearn.linear_model import LinearRegression

LR = LinearRegression()
LR.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Calculate the mean absolute error of the test set.

# %%
from sklearn.metrics import mean_absolute_error

y_pred = LR.predict(X_test)
MAE = mean_absolute_error(y_test, y_pred)
print(MAE)
# Out:
# 25693.046649516044

# %% [markdown]
# Using the trained linear regression model, predict the price of a property
# - In town Bedok
# - 4 room flat
# - Block 532
# - 89 sqm floor area
# - Bedok North Street 3, Singapore 460532
# - On the 5th storey
# - Lease commenced in 2011
# - Remaining Lease: 93 years 07 months

# %%
joblib.dump(LR, "resale-flat.pkl")
# Out:
# ['resale-flat.pkl']

# %%
# Deployment - If you want 
# Present results in a datatable
# Need to have joblib installed
# upload supporting files
# Good overall webpage aestherics

# %% [markdown]
# ## Open ended
# In HDB dataset, ‘Block’ was found to have low feature importance using the default RandomForestRegressor model. What can be done to the column and why?
